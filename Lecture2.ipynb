# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahRefaey/Cmod-A7-35T-XADC/blob/master/Lecture2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from urllib.request import urlopen

# Try maybe downloading the image 
img = Image.open(requests.get('https://www.ece.rice.edu/~wakin/images/lena512.bmp',stream=True).raw)

# Show the image size.
print('Image size: ', img.size)

# Plot the image.
def display_image(img):
  plt.imshow(img, cmap='gray')
  plt.grid(False)

  
display_image(img)
plt.show()
plt.savefig("img.png")       # save the dark image
# Out:
# Image size:  (512, 512)

# %%
img = Image.open(requests.get('https://www.ece.rice.edu/~wakin/images/lena512.bmp',stream=True).raw)

plt.figure(figsize=(20,16))

# Your code <-- downsampling with no interpoloation
plt.subplot(131)
plt.title('None')
display_image(img)

# Your code <-- downsampling with bi-linear interpolation
plt.subplot(132)
plt.title('Bilinear')
display_image(img2)

# Your code <-- downsampling with bi-cubic interpolation
plt.subplot(133)
plt.title('Bicubic')
display_image(img3)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-af6d02724152> in <module>()
#      11 plt.subplot(132)
#      12 plt.title('Bilinear')
# ---> 13 display_image(img2)
#      14
#      15 # Your code <-- downsampling with bi-cubic interpolation
#
# NameError: name 'img2' is not defined
